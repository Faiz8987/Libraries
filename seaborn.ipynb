# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
gg=sns.load_dataset("Fmri")

# %%
gg.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x="timepoint",y="signal",data=gg)
plt.show()

# %%
sns.lineplot(x="timepoint",y="signal",data=gg,color="grey",hue='event',style='event')
plt.show()

# %%
import pandas as pd

# %%
qq=pd.read_csv("C:\\Users\\lenovo\\Documents\\Book2.csv")

# %%
qq.head()
# Out:
#   name  speed  legendry  wight
# 0    a      1         0    120
# 1   aa      2         0    110
# 2    z      3         0    115
# 3   zz      4         0    105
# 4   dd      5         0    200

# %%
sns.barplot(x='legendry',y='wight',data=qq,hue='legendry')
sns.set(style='whitegrid')
plt.show()

# %%
sns.barplot(x='legendry',y='wight',data=qq,palette='vlag')
plt.show()

# %%
sns.barplot(x='legendry',y='wight',data=qq,palette='rocket')
plt.show()

# %%
sns.barplot(x='legendry',y='wight',data=qq,color='black')
plt.show()

# %%
sns.barplot(x='legendry',y='wight',data=qq,palette='Blues_d')
plt.show()

# %%
sns.scatterplot(x='legendry',y='speed',data=qq,hue='wight')
plt.show()

# %%
gg.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.displot(gg['timepoint'],kde=True)
plt.show()

# %%
sns.displot(gg['timepoint'],rug=False)
plt.show()

# %%
sns.displot(gg['timepoint'],kde=True,color='black')
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
aa=sns.load_dataset("fmri")

# %%
aa.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.displot(aa["timepoint"],bins=10,color="orange")
plt.show()

# %%
aa.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
#jointplot

# %%
sns.jointplot(x="subject",y="timepoint",data=aa)
plt.show()

# %%
sns.jointplot(x="timepoint",y='signal',data=aa,color="olive")
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
aa=pd.read_csv("C:\\Users\\lenovo\\Documents\\Book2.csv")

# %%
ss=sns.load_dataset("fmri")

# %%
ss.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
from matplotlib import pyplot as plt

# %%
sns.jointplot(x="subject",y="timepoint",data=ss)
plt.show()

# %%
sns.jointplot(x="subject",y="timepoint",data=ss)
plt.show()

# %%
sns.boxenplot(x="name",y="wight",data=aa)
plt.show()

# %%
aa.head()

# %%
dd=pd.read_csv("C:\\Users\\lenovo\\Documents\\Book3.csv")

# %%
dd.head()
# Out:
#   name  speed  legendry  wight
# 0    a      1         0    120
# 1    a      2         0    110
# 2    a      3         0    115
# 3    a      4         0    105
# 4    a      5         0    200

# %%
sns.boxplot(x="name",y="wight",data=dd)
plt.show()

# %%
dd.head()

# %%
qq=pd.read_csv("C:\\Users\\lenovo\\Documents\\Book3.csv")

# %%
sns.boxenplot(x="name",y="wight",data=qq)
plt.show()

# %%
qq

# %%
dd.median()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6584\554249589.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dd.median()
# speed        37.0
# legendry      1.0
# wight       136.0
# dtype: float64

# %%
aa.head()

# %%
ss
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
ff=pd.read_csv("C:\\Users\\lenovo\\Documents\\Book1.csv")

# %%
ff.head()
# Out:
#            NAME  AGE      RELATION
# 0     HAMID ALI   80  GRAND FATHER
# 1   JAHIDA BANO   75  GRAND MOTHER
# 2     JAHID ALI   50         UNCLE
# 3  SHAFIQUE ALI   45           DAD
# 4   AZEEZA BANO   40           MOM

# %%
sns.boxplot(x="NAME",y="AGE",data=ff)
plt.show()

# %%
sns.boxplot(x="legendry",y="wight",data=aa,color="grey")
plt.show()

# %%
sns.boxplot(x="legendry",y="wight",data=aa,color="grey",linewidth=4)
plt.show()

# %%
sns.boxplot(x="legendry",y="speed",data=aa,palette="Set2",linewidth=3,order=[1,0])
plt.show()

# %%
ss.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.boxplot(x="region",y="timepoint",hue="event",data=ss,linewidth=4,palette="Set3")
plt.show()

# %%
#pairplot

# %%
sns.pairplot(ss,hue="event")
plt.show()

# %%
ss.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
